# %% [markdown]
# # Работа над решением
#
# Привет! 👋 В этом ноутбуке находится процесс *обучения модели*, *подбор гиперпараметров* и небольшой *feature engineering*.
#
# ## Разделы:
#
# ### ⚙️ Загрузка данных
# В этом разделе происходит загрузка датасетов `train.csv`, и `features.csv`.
#
#
# ### 🔧 Обработка данных
# После загрузки данных, необходимо объединить два датафрейма `features.csv` и `train.csv` в один, чтобы получить один датафрейм, на основе которого будут создаваться дополнительные признаки и обучаться модели.
#
#
# ### 👨🏻‍🏫 Обучение базовых моделей
# Далее, из большого класса различных моделей, выбираем те модели, которые *лучше всего находят закономерность в данных*, и имеют хорошую **MAE** на тренировочных и тестовых данных.
#
#
# ### 🧱 Feature Engineering
# Можно улучшить метрику **MAE** для базовых моделей, создав новые переменные на основе старых, чтобы модель смогла уловить сложные взаимосвязи между переменными.
#
# ### 🔎 Подбор гиперпараметров для моделей
# Отобрав лучшие базовые модели, можно повысить обобщающую способность с помощью подбора гиперпараметров.
#
# ### 🧪 Эксперименты с моделями
# После, можно попробовать сделать `бэггинг` или `стэкинг`, для улучшения качества модели.
#
# ### Итоговый MAE

# %% [markdown]
# # ⚙️ Загрузка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('./data/train.csv', index_col='id')
train_data.head(10)
# Out:
#           lat        lon      score
# id
# 1   57.811440  98.844164  17.674454
# 2   56.942583  43.439199  32.418674
# 3   55.527237  39.489022  12.792405
# 4   55.836358  85.525197  22.578083
# 5   55.846859  70.789687   5.387050
# 6   58.687586  72.719792  12.111353
# 7   56.797986  43.207289  16.989785
# 8   57.122465  73.230153  22.740405
# 9   58.952489  71.543960  19.603214
# 10  58.227565  70.090234  19.167879

# %%
features = pd.read_csv('./data/features.csv', index_col='id')
features.head()
# Out:
#           lat        lon  feature_1_normal  feature_2_binomial_1  \
# id
# 1   58.380263  46.664709         29.760289                     0
# 2   56.532729  45.897839         19.854677                     2
# 3   58.214490  74.643635          1.261961                     1
# 4   55.667053  62.933473         15.843298                     3
# 5   56.888499  57.741823        -10.161689                     1
#
#     feature_3_binomial_2  feature_4_gamma
# id
# 1                      4        11.512821
# 2                      5        12.653262
# 3                      6         4.866413
# 4                      4         3.741155
# 5                      5         8.643278

# %% [markdown]
# ## Как выглядят объекты ритейла на карте
#
# Чтобы посмотреть на сгенерированные координаты, часть из них можно отобразить на реальной карте, и вот как они выглядят:

# %% [markdown]
# <img src='./images/map.png'>

# %% [markdown]
# # 🔧 Обработка данных

# %% [markdown]
# ## Объединение train.csv и features.csv на основе определенных диапазонов
#
# Чтобы сгенерированные признаки из файла `features.ipynb` были осознанные, для каждого признака из `features.csv` были сделаны диапазоны с шагом **5**, чтобы можно было для определенной широты `(lat)` и долготы `(lon)` присвоить определенные значения признаков.

# %%
# Шаг разбиения на диапазоны
step = 5
features['lat_bin'] = (features['lat'] // step) * step
features['lon_bin'] = (features['lon'] // step) * step

grouped_features_df = features.groupby(['lat_bin', 'lon_bin']).mean().reset_index()

train_data['lat_bin'] = (train_data['lat'] // step) * step
train_data['lon_bin'] = (train_data['lon'] // step) * step

merged_df = pd.merge(train_data, grouped_features_df, on=['lat_bin', 'lon_bin'], how='left')
merged_df.drop(['lat_bin', 'lon_bin'], axis=1, inplace=True)

# %% [markdown]
# ## Пересборка датафрейма

# %%
merged_df = merged_df[[col for col in merged_df.columns if col != 'score'] + ['score']]
merged_df = merged_df.drop(['lat_y', 'lon_y'], axis=1)
merged_df['id'] = range(0, 2000)
merged_df = merged_df.set_index('id')

merged_df.head()
# Out:
#         lat_x      lon_x  feature_1_normal  feature_2_binomial_1  \
# id
# 0   57.811440  98.844164          9.192944              1.529680
# 1   56.942583  43.439199          5.440447              1.471111
# 2   55.527237  39.489022          2.941418              1.458599
# 3   55.836358  85.525197          4.487308              1.523207
# 4   55.846859  70.789687          5.440118              1.458150
#
#     feature_3_binomial_2  feature_4_gamma      score
# id
# 0               4.237443         8.252921  17.674454
# 1               4.115556         9.485485  32.418674
# 2               4.292994         8.312207  12.792405
# 3               4.206751         9.187135  22.578083
# 4               4.259912         8.957588   5.387050

# %% [markdown]
# # 👨🏻‍🏫 Обучение базовых моделей

# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 8.9 MB/s eta 0:00:00
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

X = merged_df.drop('score', axis=1)
y = merged_df['score']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=0)

# %% [markdown]
# Создание функций для обучения на тренировочных и тестовых данных для нескольких моделей.

# %%
def train_pipe_test(models, X_tr, X_te,
                    y_tr, y_te):
    set_models = {}
    for model in models:
        temp_pipe = Pipeline([('scaler', StandardScaler()),
                              (f"{type(model).__name__}", model)])
        temp_pipe.fit(X_tr, y_tr)

        set_models[type(model).__name__] = np.mean(np.abs(temp_pipe.predict(X_te) - y_te))

    return set_models

def train_pipe_train(models, X_tr, X_te,
                     y_tr, y_te):
    set_models = {}
    for model in models:
        temp_pipe = Pipeline([('scaler', StandardScaler()),
                              (f"{type(model).__name__}", model)])
        temp_pipe.fit(X_tr, y_tr)

        set_models[type(model).__name__] = np.mean(np.abs(temp_pipe.predict(X_tr) - y_tr))

    return set_models

# %%
# %%capture
models_list = [LinearRegression(), Lasso(), CatBoostRegressor(),
               KNeighborsRegressor(), DecisionTreeRegressor(), Ridge(), RandomForestRegressor()]

results_train = train_pipe_train(models_list, X_train, X_test, y_train, y_test)
results_test = train_pipe_test(models_list, X_train, X_test, y_train, y_test)

# %% [markdown]
# ### Значение MAE на тренировочных и тестовых данных

# %%
print('Train MAE')
results_train
# Out:
# Train MAE
# {'LinearRegression': 5.686480312525423,
#  'Lasso': 5.700648938071226,
#  'CatBoostRegressor': 4.163472699897435,
#  'KNeighborsRegressor': 4.954122434426852,
#  'DecisionTreeRegressor': 0.0,
#  'Ridge': 5.686484602002604,
#  'RandomForestRegressor': 2.2634019922259783}

# %%
print('Test MAE')
results_test
# Out:
# Test MAE
# {'LinearRegression': 5.522888953077804,
#  'Lasso': 5.512036358375745,
#  'CatBoostRegressor': 5.807614878096968,
#  'KNeighborsRegressor': 6.026299408743917,
#  'DecisionTreeRegressor': 8.309375725759905,
#  'Ridge': 5.522855946758243,
#  'RandomForestRegressor': 5.956153123310924}

# %%
def plot_dicts(dict1, dict2):
    plt.figure(figsize=(10, 6))

    plt.bar(dict1.keys(), dict1.values(), alpha=0.9, label='Тренировочный MAE', color='red')

    plt.bar(dict2.keys(), dict2.values(), alpha=0.1, label='Тестовый MAE', color='green')

    plt.xlabel('Модели')
    plt.ylabel('Значение MAE')
    plt.title('Сравнение значения MAE моделей на тренировочных и тестовых данных')
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

plot_dicts(results_train, results_test)

# %% [markdown]
# ### Проверка, есть ли мультиколлинеарность

# %%
fig, ax = plt.subplots(figsize=(8, 8))

corr = X.corr()
lower = corr.where(np.tril(np.ones(corr.shape), k=-1).astype(np.bool_))

sns.heatmap(lower, annot=True,
            fmt='.2f', cbar=False, center=0, ax=ax, cmap='viridis');

# %% [markdown]
# В принципе, зависимость между переменными слабая, поэтому удалять переменные не стоит.

# %% [markdown]
# # 🧱 Feature Engineering

# %% [markdown]
# ## Генерация новых переменных

# %%
feature_1 = np.sin(X['feature_1_normal']) + np.log10(X['feature_2_binomial_1']) - \
    np.cos(X['feature_1_normal']) * np.exp(X['feature_3_binomial_2']) * np.sqrt(np.abs(X['feature_4_gamma']))

feature_2 = np.exp(X['feature_3_binomial_2']) * np.sqrt(abs(X['feature_2_binomial_1'])) * np.log(X['feature_1_normal']) / np.sqrt(abs(X['feature_4_gamma']))

feature_1_df = pd.DataFrame(data=feature_1, columns=['new_feature_1'])
feature_2_df = pd.DataFrame(data=feature_2, columns=['new_feature_2'])

# %%
new_merged_df = merged_df.merge(feature_1_df, on='id')
new_merged_df = new_merged_df.merge(feature_2_df, on='id')

new_merged_df.head()
# Out:
#         lat_x      lon_x  feature_1_normal  feature_2_binomial_1  \
# id
# 0   57.811440  98.844164          9.192944              1.529680
# 1   56.942583  43.439199          5.440447              1.471111
# 2   55.527237  39.489022          2.941418              1.458599
# 3   55.836358  85.525197          4.487308              1.523207
# 4   55.846859  70.789687          5.440118              1.458150
#
#     feature_3_binomial_2  feature_4_gamma      score  new_feature_1  \
# id
# 0               4.237443         8.252921  17.674454     193.978465
# 1               4.115556         9.485485  32.418674    -126.178766
# 2               4.292994         8.312207  12.792405     207.149101
# 3               4.206751         9.187135  22.578083      44.625535
# 4               4.259912         8.957588   5.387050    -141.540361
#
#     new_feature_2
# id
# 0       66.121322
# 1       40.882162
# 2       33.075852
# 3       41.040445
# 4       48.386486

# %% [markdown]
# ## Проверка мультиколлинеарности при добавлении новых переменных

# %%
X_new = new_merged_df.drop(['feature_1_normal', 'score'], axis=1)
y_new = new_merged_df['score']

# %%
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X_new, y_new,
                                                            test_size=0.2,
                                                            random_state=0)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

corr = X_new.corr()
lower = corr.where(np.tril(np.ones(corr.shape), k=-1).astype(np.bool_))

sns.heatmap(lower, annot=True,
            fmt='.2f', cbar=False, center=0, ax=ax, cmap='viridis');

# %% [markdown]
# ## Проверка насколько стало лучше MAE с новыми переменными

# %%
# %%capture

results_train_new = train_pipe_train(models_list, X_train_1, X_test_1, y_train_1, y_test_1)
results_test_new = train_pipe_test(models_list, X_train_1, X_test_1, y_train_1, y_test_1)

# %%
print('Train MAE with new features')
results_train_new
# Out:
# Train MAE with new features
# {'LinearRegression': 5.68718534121135,
#  'Lasso': 5.700648938071226,
#  'CatBoostRegressor': 4.190284995610897,
#  'KNeighborsRegressor': 4.954122434426852,
#  'DecisionTreeRegressor': 0.0,
#  'Ridge': 5.687187625210623,
#  'RandomForestRegressor': 2.2478619535129623}

# %%
print('Test MAE with new features')
results_test_new
# Out:
# Test MAE with new features
# {'LinearRegression': 5.517266604686665,
#  'Lasso': 5.512036358375745,
#  'CatBoostRegressor': 5.75666149293331,
#  'KNeighborsRegressor': 6.026299408743917,
#  'DecisionTreeRegressor': 7.834534294276542,
#  'Ridge': 5.517240723930222,
#  'RandomForestRegressor': 5.937562460541834}

# %%
plot_dicts(results_train_new, results_test_new)

# %% [markdown]
# Значение **MAE** стало немного меньше, а значит, новые переменные помогли моделям лучше понимать данные.

# %% [markdown]
# # 🔎 Подбор гиперпараметров для моделей
#
# Исходя из последнего графика, целесообразнее будет выбрать следующие модели для подбора гиперпараметров:
#
# * **RandomForestRegressor**
# * **DecisionTreeRegressor**
# * **CatBoostRegressor**

# %%
new_df = new_merged_df

X = new_df.drop('score', axis=1)
y = new_df['score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=0)

# %% [markdown]
# ### RandomForestRegressor

# %%
rf_params = {
    'RandomForestRegressor__bootstrap': [True, False],
    'RandomForestRegressor__max_depth': [10, 30, 50, 90, None],
    'RandomForestRegressor__max_features': ['auto', 'sqrt'],
    'RandomForestRegressor__min_samples_leaf': [1, 2, 4],
    'RandomForestRegressor__min_samples_split': [2, 5, 10],
    'RandomForestRegressor__n_estimators': [200, 400, 600, 1000]
}

# %%
from sklearn.model_selection import GridSearchCV

rf_pipe = Pipeline([('scaler', StandardScaler()),
                    ('RandomForestRegressor', RandomForestRegressor(n_jobs=-1))])

rf_cv = GridSearchCV(estimator=rf_pipe, cv=5, param_grid=rf_params, scoring='neg_mean_absolute_error')

rf_cv.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# ...

# %%
rf_cv.best_params_
# Out:
# {'RandomForestRegressor__bootstrap': True,
#  'RandomForestRegressor__max_depth': 10,
#  'RandomForestRegressor__max_features': 'sqrt',
#  'RandomForestRegressor__min_samples_leaf': 4,
#  'RandomForestRegressor__min_samples_split': 2,
#  'RandomForestRegressor__n_estimators': 200}

# %%
rf_cv.score(X_test, y_test)
# Out:
# -5.603409076941968

# %% [markdown]
# ## DecisionTreeRegressor

# %%
dtr_param_grid = {
    'DecisionTreeRegressor__max_depth': [None, 5, 10, 15, 20],
    'DecisionTreeRegressor__min_samples_split': [2, 5, 10],
    'DecisionTreeRegressor__min_samples_leaf': [1, 2, 4],
    'DecisionTreeRegressor__max_features': ['sqrt', 'log2'],
    'DecisionTreeRegressor__min_weight_fraction_leaf': [0.0, 0.5, 0.8],
    'DecisionTreeRegressor__criterion': ['absolute_error']
}

# %%
from sklearn.model_selection import GridSearchCV

dtr_pipe = Pipeline([('scaler', StandardScaler()),
                     ('DecisionTreeRegressor', DecisionTreeRegressor())])

dtr_cv = GridSearchCV(estimator=dtr_pipe, cv=5, param_grid=dtr_param_grid, scoring='neg_mean_absolute_error')

dtr_cv.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 450 fits failed out of a total of 1350.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 450 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py", line 1247, in fit
#     super().fit(
# ...

# %%
decisiontree_params = dtr_cv.best_params_

# %%
decisiontree_params
# Out:
# {'DecisionTreeRegressor__criterion': 'absolute_error',
#  'DecisionTreeRegressor__max_depth': 20,
#  'DecisionTreeRegressor__max_features': 'sqrt',
#  'DecisionTreeRegressor__min_samples_leaf': 2,
#  'DecisionTreeRegressor__min_samples_split': 5,
#  'DecisionTreeRegressor__min_weight_fraction_leaf': 0.5}

# %%
np.mean(np.abs(y_test - dtr_cv.predict(X_test)))
# Out:
# 5.5240507776247405

# %%
np.mean(np.abs(y_train - dtr_cv.predict(X_train)))
# Out:
# 5.700171711363075

# %%
pipe_check  = Pipeline([('scaler', StandardScaler()),
                        ('DecisionTreeRegressor', DecisionTreeRegressor(criterion='absolute_error', max_depth=20,
                                                                        max_features='sqrt', min_samples_leaf=2,
                                                                        min_samples_split=5, min_weight_fraction_leaf=0.5))])
pipe_check.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('DecisionTreeRegressor',
#                  DecisionTreeRegressor(criterion='absolute_error', max_depth=20,
#                                        max_features='sqrt', min_samples_leaf=2,
#                                        min_samples_split=5,
#                                        min_weight_fraction_leaf=0.5))])

# %%
np.mean(np.abs(y_test - pipe_check.predict(X_test)))
# Out:
# 5.5240507776247405

# %% [markdown]
# ## CatBoostRegressor

# %%
# %%capture
param_cbr = {
    'CatBoostRegressor__iterations': [100, 200, 500, 1000, 1500],
    'CatBoostRegressor__learning_rate': np.arange(0.001, 0.011, 0.002),
    'CatBoostRegressor__depth': np.arange(4, 11, 2),
    'CatBoostRegressor__l2_leaf_reg': np.arange(2, 11, 2),
    'CatBoostRegressor__random_strength': np.arange(0, 11, 2),
}

pipe_cbr = Pipeline([('scaler', StandardScaler()),
                     ('CatBoostRegressor', CatBoostRegressor())])

cbr_cv = GridSearchCV(estimator=pipe_cbr, cv=3, param_grid=param_cbr, scoring='neg_mean_absolute_error')

cbr_cv.fit(X_train, y_train)

# %%
np.mean(np.abs(y_train - cbr_cv.predict(X_train)))
# Out:
# 4.176275332379851

# %%
cbr_cv.best_params_
# Out:
# {'CatBoostRegressor__depth': 10,
#  'CatBoostRegressor__iterations': 100,
#  'CatBoostRegressor__l2_leaf_reg': 10,
#  'CatBoostRegressor__learning_rate': 0.005,
#  'CatBoostRegressor__random_strength': 0}

# %%
cbr_cv.best_score_
# Out:
# -5.696497113640857

# %%
np.mean(np.abs(y_test - cbr_cv.predict(X_test)))
# Out:
# 5.507011260970309

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_train, cbr_cv.predict(X_train))
# Out:
# 5.583151926198936

# %%
mean_absolute_error(y_test, cbr_cv.predict(X_test))
# Out:
# 5.507011260970309

# %% [markdown]
# ## 🧪 Эксперименты с моделями
#
# Попробуем сделать стэкинг из трёх этих моделей с лучшими параметрами и замерить итоговый `MAE`

# %%
from sklearn.ensemble import StackingRegressor

pipe_rf = Pipeline([('scaler', StandardScaler()),
                    ('RandomForestRegressor', RandomForestRegressor(bootstrap=True, max_depth=10,
                                                                    max_features='sqrt', min_samples_leaf=4,
                                                                    min_samples_split=2, n_estimators=200))])
pipe_catboost = Pipeline([('scaler', StandardScaler()),
                          ('CatBoostRegressor', CatBoostRegressor(depth=10, iterations=100,
                                                                  l2_leaf_reg=10, learning_rate=0.005,
                                                                  random_strength=0))])

estimators = [
    ('RF', pipe_rf),
    ('CBR', pipe_catboost)
]

final_estimator = DecisionTreeRegressor(criterion='absolute_error', max_depth=20,
                                        max_features='sqrt', min_samples_leaf=2,
                                        min_samples_split=5, min_weight_fraction_leaf=0.5)

stacking_model = StackingRegressor(
    estimators=estimators,
    final_estimator=final_estimator,
    cv=3
)

# %%
# %%capture
stacking_model.fit(X_train, y_train)

# %% [markdown]
# ## Итоговый MAE

# %%
train_preds = stacking_model.predict(X_train)
test_preds = stacking_model.predict(X_test)

train_error = mean_absolute_error(y_train, train_preds)
test_error = mean_absolute_error(y_test, test_preds)

print(f"MAE на трейне при использовании стекинга: {train_error}")
print(f"MAE на тесте при использовании стекинга: {test_error}")
# Out:
# MAE на трейне при использовании стекинга: 5.510888602863632
# MAE на тесте при использовании стекинга: 5.5104950657544745

# %%
# Экспорт модели
import pickle
pickle.dump(stacking_model, open('stacking_regressor_model.sav', 'wb'))
